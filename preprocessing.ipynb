# %%
import pandas as pd
import numpy as np
import spacy
import string
import re
import nltk

# %%
# Create our list of punctuation marks
punctuations = string.punctuation

# Create our list of stopwords
nlp = spacy.load('en_core_web_lg')
STOPWORDS = spacy.lang.en.stop_words.STOP_WORDS

# %%
df = pd.read_csv('TrainingDS.csv')
df_sample = pd.read_csv('Sample Submission.csv')
df_test = pd.read_csv('TestingDS.csv')
df.head()
# Out:
#    ID                                               Text  Class
# 0   1  Trump supporters needed to say the 4 Democrats...      0
# 1   2  Send them back!!Why the hell are they even her...      1
# 2   3  Yeah...Im wondering if send them back works fo...      1
# 3   4  I know you realize you cant pretend that you d...      1
# 4   5  Donny, you owe all people an apology for appla...      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      1500 non-null   int64
#  1   Text    1500 non-null   object
#  2   Class   1500 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 35.3+ KB

# %%
df.describe()
# Out:
#                 ID        Class
# count  1500.000000  1500.000000
# mean    750.500000     0.386667
# std     433.157015     0.487149
# min       1.000000     0.000000
# 25%     375.750000     0.000000
# 50%     750.500000     0.000000
# 75%    1125.250000     1.000000
# max    1500.000000     1.000000

# %%
# string to lower
df["text_new"] = df["Text"].str.lower()
df.head()
# Out:
#    ID                                               Text  Class  \
# 0   1  Trump supporters needed to say the 4 Democrats...      0
# 1   2  Send them back!!Why the hell are they even her...      1
# 2   3  Yeah...Im wondering if send them back works fo...      1
# 3   4  I know you realize you cant pretend that you d...      1
# 4   5  Donny, you owe all people an apology for appla...      0
#
#                                             text_new
# 0  trump supporters needed to say the 4 democrats...
# 1  send them back!!why the hell are they even her...
# 2  yeah...im wondering if send them back works fo...
# 3  i know you realize you cant pretend that you d...
# 4  donny, you owe all people an apology for appla...

# %%
# add spaces after symbols
def setSpace(val):
    return re.sub(r'(\W)', r'\1 ', val)

df["text_new"] = df["text_new"].apply(setSpace)
df.head()
# Out:
#    ID                                               Text  Class  \
# 0   1  Trump supporters needed to say the 4 Democrats...      0
# 1   2  Send them back!!Why the hell are they even her...      1
# 2   3  Yeah...Im wondering if send them back works fo...      1
# 3   4  I know you realize you cant pretend that you d...      1
# 4   5  Donny, you owe all people an apology for appla...      0
#
#                                             text_new
# 0  trump  supporters  needed  to  say  the  4  de...
# 1  send  them  back! ! why  the  hell  are  they ...
# 2  yeah. . . im  wondering  if  send  them  back ...
# 3  i  know  you  realize  you  cant  pretend  tha...
# 4  donny,   you  owe  all  people  an  apology  f...

# %%
# remove punct
PUNCT_TO_REMOVE = string.punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans('', '', PUNCT_TO_REMOVE))

df["text_new"] = df["text_new"].apply(lambda text: remove_punctuation(text))
df.head()
# Out:
#    ID                                               Text  Class  \
# 0   1  Trump supporters needed to say the 4 Democrats...      0
# 1   2  Send them back!!Why the hell are they even her...      1
# 2   3  Yeah...Im wondering if send them back works fo...      1
# 3   4  I know you realize you cant pretend that you d...      1
# 4   5  Donny, you owe all people an apology for appla...      0
#
#                                             text_new
# 0  trump  supporters  needed  to  say  the  4  de...
# 1  send  them  back  why  the  hell  are  they  e...
# 2  yeah   im  wondering  if  send  them  back  wo...
# 3  i  know  you  realize  you  cant  pretend  tha...
# 4  donny   you  owe  all  people  an  apology  fo...

# %%
def remove_stopwords(text):
    """custom function to remove the stopwords"""
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

df["text_new"] = df["text_new"].apply(remove_stopwords)
df.head()
# Out:
#    ID                                               Text  Class  \
# 0   1  Trump supporters needed to say the 4 Democrats...      0
# 1   2  Send them back!!Why the hell are they even her...      1
# 2   3  Yeah...Im wondering if send them back works fo...      1
# 3   4  I know you realize you cant pretend that you d...      1
# 4   5  Donny, you owe all people an apology for appla...      0
#
#                                             text_new
# 0  trump supporters needed 4 democrats socialist ...
# 1  send hell im sick hearing greatest country gre...
# 2  yeah im wondering send works wife 1 amp 3 ykno...
# 3  know realize cant pretend didnt know obama beg...
# 4  donny owe people apology applauding horrible c...
